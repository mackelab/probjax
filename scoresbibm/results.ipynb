# %%
import matplotlib.pyplot as plt


import seaborn as sns
import numpy as np

from main.plot import plot_metric_by_num_simulations, use_style, multi_plot
from main.utils import query

import warnings
warnings.filterwarnings("ignore")

# %%
query("results/benchmark", task="two_moons")
# Out:
# task=='two_moons'
#    method       task  num_simulations  seed  model_id metric     value  \
# 0     npe  two_moons             1000     0         0   c2st  0.727970
# 1     npe  two_moons            10000     0         1   c2st  0.584280
# 2     npe  two_moons           100000     0         2   c2st  0.531095
# 6     nre  two_moons             1000     0        10   c2st  0.831645
# 8     nre  two_moons            10000     0        12   c2st  0.761505
# 11    nre  two_moons           100000     0        17   c2st  0.548065
# 12    nle  two_moons             1000     0        18   c2st  0.652120
# 13    nle  two_moons            10000     0        19   c2st  0.553835
# 16    nle  two_moons           100000     0        22   c2st  0.520405
# 18   nspe  two_moons             1000     0        24   c2st  0.630070
# 20   nspe  two_moons            10000     0        26   c2st  0.606330
# 27   nspe  two_moons           100000     0        33   c2st  0.549785
#
#                                                   cfg
# 0   {'name': 'benchmark', 'seed': 0, 'save_model':...
# 1   {'name': 'benchmark', 'seed': 0, 'save_model':...
# 2   {'name': 'benchmark', 'seed': 0, 'save_model':...
# 6   {'name': 'benchmark', 'seed': 0, 'save_model':...
# 8   {'name': 'benchmark', 'seed': 0, 'save_model':...
# 11  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 12  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 13  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 16  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 18  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 20  {'name': 'benchmark', 'seed': 0, 'save_model':...
# 27  {'name': 'benchmark', 'seed': 0, 'save_model':...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot("results/benchmark", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='gaussian_linear'
# task=='gaussian_mixture'
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# task=='slcp'
# task=='two_moons'
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial

# %%
with use_style("pyloric"):
    fig, ax = plot_metric_by_num_simulations("results/benchmark", hue="task")
fig
