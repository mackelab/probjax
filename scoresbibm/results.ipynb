# %%
import matplotlib.pyplot as plt


import seaborn as sns
import numpy as np

from main.plot import plot_metric_by_num_simulations, use_style, multi_plot
from main.utils import query

import warnings
warnings.filterwarnings("ignore")

# %%
query("results/benchmark")
# Out:
#                          method              task  num_simulations  seed  \
# 0                           npe         two_moons             1000     0
# 1                           npe         two_moons            10000     0
# 2                           npe         two_moons           100000     0
# 3                           npe  gaussian_mixture             1000     0
# 4                           npe  gaussian_mixture            10000     0
# ..                          ...               ...              ...   ...
# 76      score_transformer_graph  gaussian_mixture           100000     0
# 77      score_transformer_graph   gaussian_linear            10000     0
# 78  score_transformer_posterior              slcp           100000     0
# 79      score_transformer_graph              slcp           100000     0
# 80  score_transformer_posterior   gaussian_linear           100000     0
#
#     model_id metric     value  \
# 0          0   c2st  0.727970
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot("results/benchmark", "task", "metric", plot_metric_by_num_simulations, hue="method")
    plt.show()
    fig.savefig("benchmark.svg")
# Out:
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot("../results/benchmark4", "task", "metric", plot_metric_by_num_simulations, hue="method")
    plt.show()
    fig.savefig("benchmark.svg")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...
