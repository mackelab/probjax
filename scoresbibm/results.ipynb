# %%
import matplotlib.pyplot as plt


import seaborn as sns
import numpy as np

from scoresbibm.src.utils.plot import plot_metric_by_num_simulations, use_style, multi_plot
from scoresbibm.src.utils.data_utils import query

import warnings
warnings.filterwarnings("ignore")

# %%
fig, axes = multi_plot("results/bm_vpsde", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'

# %%
fig, axes = multi_plot("results/bm_all_cond", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='marcov_chain_all_cond'
# task=='slcp_all_cond'
# task=='tree_all_cond'
# task=='two_moons_all_cond'

# %%
fig, axes = multi_plot("results/bm_vesde", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'

# %%
fig, axes = multi_plot("results/bm_vesde_all_cond", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='marcov_chain_all_cond'
# task=='slcp_all_cond'
# task=='tree_all_cond'
# task=='two_moons_all_cond'

# %%
fig, axes = multi_plot("results/bm_base", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'

# %%
fig, axes = multi_plot("results/benchmark_main33", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fig, axes = multi_plot("results/benchmark_main33", "task", "metric", plot_metric_by_num_simulations, hue="method")
#
# File /mnt/qb/work/macke/mgloeckler90/probjax/scoresbibm/src/utils/plot.py:204, in multi_plot(name, cols, rows, plot_fn, fig_title, y_label_by_row, y_labels, scilimit, x_labels, y_lims, fontsize_title, figsize_per_row, figsize_per_col, legend_bbox_to_anchor, legend_title, legend_ncol, legend_kwargs, fig_legend, verbose, **kwargs)
#     182 def multi_plot(
#     183     name,
#     184     cols,
#    (...)
#     202     **kwargs,
#     203 ):
# --> 204     df = query(name, **kwargs)
#     206     df = df.sort_values(cols, na_position="first", key=get_sorting_key_fn(cols))
#     207     cols_vals = df[cols].dropna().unique()
#
# ...

# %%
fig, axes = multi_plot("../results/sbibm_benchmark_vesde_all_cond3,method", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 fig, axes = multi_plot("../results/sbibm_benchmark_vesde_all_cond3,method", "task", "metric", plot_metric_by_num_simulations, hue="method")
#
# File /mnt/qb/work/macke/mgloeckler90/probjax/scoresbibm/src/utils/plot.py:204, in multi_plot(name, cols, rows, plot_fn, fig_title, y_label_by_row, y_labels, scilimit, x_labels, y_lims, fontsize_title, figsize_per_row, figsize_per_col, legend_bbox_to_anchor, legend_title, legend_ncol, legend_kwargs, fig_legend, verbose, **kwargs)
#     182 def multi_plot(
#     183     name,
#     184     cols,
#    (...)
#     202     **kwargs,
#     203 ):
# --> 204     df = query(name, **kwargs)
#     206     df = df.sort_values(cols, na_position="first", key=get_sorting_key_fn(cols))
#     207     cols_vals = df[cols].dropna().unique()
#
# ...

# %%
fig, axes = multi_plot("../results/benchmark_main4", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'probjax (Python 3.11.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, axes = multi_plot("/mnt/qb/work/macke/mgloeckler90/probjax/results/benchmark_vesde_all_cond", "task", "metric", plot_metric_by_num_simulations, hue="method")
# Out:
# task=='marcov_chain_all_cond'
# task=='tree_all_cond'
# task=='two_moons_all_cond'

# %%
fig, axes = multi_plot("../results/benchmark_main", "task", "metric", plot_metric_by_num_simulations, hue="method")

# %%
fig, axes = multi_plot("../results/benchmark_all_cond", "task", "metric", plot_metric_by_num_simulations, hue="method")

# %%
with use_style("pyloric"):
    fig, axes = multi_plot("../results/benchmark_vesde", "task", "metric", plot_metric_by_num_simulations, hue="method")
    plt.show()
    #fig.savefig("benchmark.svg")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'probjax (Python 3.11.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with use_style("pyloric"):
    fig, axes = multi_plot("../results/benchmark4", "task", "metric", plot_metric_by_num_simulations, hue="method")
    plt.show()
    fig.savefig("benchmark.svg")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# task=='gaussian_linear'
# task=='gaussian_mixture'
# task=='slcp'
# task=='two_moons'
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...
