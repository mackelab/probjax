# %%
# %reload_ext autoreload
# %autoreload 2
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

from flax import nnx

from probjax.nn import GaussianFourierEmbedding
from probjax.nn.nets.flow_matching_model import LinearMeanFlow
from functools import partial

# %%
# MNIST data
from datasets import load_dataset
import numpy as np

dataset = load_dataset('mnist', keep_in_memory=True)

dataset.set_format(type='numpy', columns=['image'])

# %%
import scipy
def img_aug(x):
    xs_batch = x["image"]
    xs_batch = scipy.ndimage.rotate(xs_batch, np.random.uniform()*10, axes=(1,2), reshape=False)

    # Normalize to [0, 1] and add small uniform noise for dequantization
    xs_batch = xs_batch.astype(np.float32) / 255.0
    xs_batch += np.random.uniform(0, 1/255, xs_batch.shape)
    # Move to [-1,1]
    xs_batch = 2*xs_batch - 1
    xs_batch = np.clip(xs_batch, -1.0, 1.0)
    return xs_batch[..., None] # Add channel dimension

# %%
from probjax.nn.io_util import DataLoader

loader = DataLoader(dataset["train"],batch_size=256, num_prefetch_host=64, num_prefetch_device=4, shard=False, host_transforms=img_aug, num_async_workers=4)

# %%
datastream = iter(loader)

# %%
images = next(datastream)[:16,:,:,0]
stacked_images = np.vstack([np.hstack(images[i*4:(i+1)*4]) for i in range(4)])

plt.figure(figsize=(10, 10))
plt.imshow(stacked_images, cmap="gray")
plt.axis('off')
plt.show()

# %%
from probjax.nn.nets.unets import UNet, Conv, ConvTranspose, ResnetBlock, ResizeConv
from functools import partial
import time

# %%
xs = []
for i in range(5000):
    xs.append(next(datastream))
    time.sleep(0.001)


std1 = np.concatenate(xs, axis=0).std(0)
mu1 = np.concatenate(xs, axis=0).mean(0)
del xs

# %%
shapes = [(16,16), (8,8),(4,4)]
conv_up_cls = [partial(ResizeConv, out_shape=shape) for shape in shapes]
conv_down_cls = [partial(ResizeConv, out_shape=shape)for shape in shapes]

# Alternatively try ConvTranspose
# conv_up_cls = partial(ConvTranspose, kernel_size=(3,3))
# conv_down_cls = partial(Conv, kernel_size=(3,3))

# %%
class Denoiser(nnx.Module):
    def __init__(self, rngs) -> None:
        self.time_embedding1 = GaussianFourierEmbedding(1,256, rngs=rngs, learnable=True)
        # Pass norm=nnx.GroupNorm instead of num_groups to UNet/ResnetBlock
        self.net = UNet(
            1,
            rngs=rngs,
            kernel_size=(2,2),
            strides=(1,1),
            kernel_size_resnet=(3,3),
            out_features=[128,256,384,512],
            context_features=512,
            use_attention=[False, False,True,True],
            conv_down_cls = conv_down_cls,
            conv_up_cls = conv_up_cls,
            dtype=jnp.bfloat16,
            precision="BF16_BF16_F32",
            preferred_element_type=jnp.float32,
        )

    def __call__(self, t, x, r, *args, **kwargs):
        t_embed = self.time_embedding1(t)
        tr_embed = self.time_embedding1(t-r)
        time_embed = jnp.concatenate([t_embed, tr_embed], axis=-1)
        out = self.net(x, context=time_embed, *args, **kwargs)
        return out

net = Denoiser(nnx.Rngs(0))
model = LinearMeanFlow(net, std1=std1, mu1=mu1)
params = nnx.state(model, nnx.Param)

# %%
x = next(datastream)
plt.imshow(x[0])
plt.show()
plt.imshow(model(jnp.ones((256,1,1,1))*1.,x,verbose=True)[0])
plt.colorbar()
# Out:
# Could not load symbol cuFuncGetName. Error: /lib64/libcuda.so.1: undefined symbol: cuFuncGetName
# Down: (256, 28, 28, 128)
# Down: (256, 16, 16, 256)
# Down: (256, 8, 8, 384)
# Mid: (256, 4, 4, 512)
# Up: (256, 4, 4, 384)
# Up: (256, 8, 8, 256)
# 2025-09-12 16:14:44.140818: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[256,16,16,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,16,16,512]{3,2,1,0}, bf16[256,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:14:44.624791: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.484079493s
# Trying algorithm eng0{} for conv (bf16[256,16,16,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,16,16,512]{3,2,1,0}, bf16[256,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# Up: (256, 16, 16, 128)
# 2025-09-12 16:14:50.336231: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[256,28,28,128]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[128,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:14:50.521930: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.185787774s
# Trying algorithm eng0{} for conv (bf16[256,28,28,128]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[128,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...

# %%
# Count parameters
print("Number of parameters: ", sum(np.prod(v.shape) for v in jax.tree_util.tree_leaves(params)))
# Out:
# Number of parameters:  40255264

# %%
def loss_fn(params, x, rng):
    nnx.update(model, params)
    return model.loss(rng, x, axis=(-3,-2,-1), adaptive_weight_p=0.8)

# %%
loss_fn(params, next(datastream), jax.random.key(1))
# Out:
# (256, 28, 28, 1) (256, 28, 28, 1)
# Array(3.463, dtype=float32)

# %%
from functools import partial
import optax

opt = optax.chain(optax.adaptive_grad_clip(5.), optax.adam(1e-4))
opt_state = opt.init(params)

@jax.jit
def update(params, opt_state, x, rng):
    loss, grads = jax.value_and_grad(loss_fn)(params, x, rng)
    updates, opt_state = opt.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss

def train_step(params, opt_state, xs, rng):
    params, opt_state, losses = update(params, opt_state, xs, rng)
    return params, opt_state, jnp.mean(losses)

# %%
key = jax.random.key(2)

# %%
params, opt_state, loss = train_step(params, opt_state, next(datastream), key)
# Out:
# (256, 28, 28, 1) (256, 28, 28, 1)
# 2025-09-12 16:15:46.045269: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[256,28,28,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,128]{3,2,1,0}, bf16[128,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:15:46.228556: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.183393944s
# Trying algorithm eng0{} for conv (bf16[256,28,28,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,128]{3,2,1,0}, bf16[128,3,3,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:15:48.824488: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[256,16,16,512]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,16,16,256]{3,2,1,0}, bf16[256,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:15:49.300693: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.476273084s
# Trying algorithm eng0{} for conv (bf16[256,16,16,512]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,16,16,256]{3,2,1,0}, bf16[256,3,3,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:16:15.704425: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng19{k2=1} for conv (bf16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[256,28,28,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:16:15.968329: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.263996007s
# Trying algorithm eng19{k2=1} for conv (bf16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[256,28,28,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:16:16.968447: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng19{k2=0} for conv (bf16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[256,28,28,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-09-12 16:16:17.352846: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.384480929s
# Trying algorithm eng19{k2=0} for conv (bf16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(bf16[256,28,28,256]{3,2,1,0}, bf16[256,28,28,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...

# %%
ema = optax.ema(0.9999)
ema_state = ema.init(params)

# %%
# Example training iteration
for i in range(100):
    l = 0.
    for j in range(500):
        key, key_data, key_loss = jax.random.split(key, 3)
        xs = next(datastream)
        params, opt_state, loss = train_step(params, opt_state, xs, key_loss)
        l += loss
        ema_params, ema_state = ema.update(params, ema_state)
    print(l/500)
# Out:
# (96, 28, 28, 1) (96, 28, 28, 1)
# 3.0196807
# 2.806313
# 2.7650304
# 2.7501063
# 2.7434309
# 2.7403672
# 2.7375267
# 2.719599
# 2.7183158
# 2.715726
# 2.7100325
# 2.7132902
# 2.7087746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 9
#       7     params, opt_state, loss = train_step(params, opt_state, xs, key_loss)
#       8     l += loss
# ----> 9     ema_params, ema_state = ema.update(params, ema_state)
#      10 print(l/500)
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/optax/transforms/_accumulation.py:121, in ema.<locals>.update_fn(***failed resolving arguments***)
#     119 def update_fn(updates, state, params=None):
#     120   del params
# --> 121   updates = new_ema = optax.tree.update_moment(
#     122       updates, state.ema, decay, order=1
#     123   )
#     124   count_inc = numerics.safe_increment(state.count)
#     125   if debias:
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/optax/tree_utils/_tree_math.py:332, in tree_update_moment(updates, moments, decay, order)
#     330 def tree_update_moment(updates, moments, decay, order):
#     331   """Compute the exponential moving average of the `order`-th moment."""
# --> 332   return jax.tree.map(
#     333       lambda g, t: (
#     334           (1 - decay) * (g**order) + decay * t if g is not None else None
#     335       ),
#     336       updates,
#     337       moments,
#     338       is_leaf=lambda x: x is None,
#     339   )
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/jax/_src/tree.py:155, in map(f, tree, is_leaf, *rest)
#     115 def map(f: Callable[..., Any],
#     116         tree: Any,
#     117         *rest: Any,
#     118         is_leaf: Callable[[Any], bool] | None = None) -> Any:
#     119   """Maps a multi-input function over pytree args to produce a new pytree.
#     120
#     121   Args:
#    (...)    153     - :func:`jax.tree.reduce`
#     154   """
# --> 155   return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/jax/_src/tree_util.py:361, in tree_map(f, tree, is_leaf, *rest)
#     359 leaves, treedef = tree_flatten(tree, is_leaf)
#     360 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 361 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/jax/_src/tree_util.py:361, in <genexpr>(.0)
#     359 leaves, treedef = tree_flatten(tree, is_leaf)
#     360 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 361 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/optax/tree_utils/_tree_math.py:334, in tree_update_moment.<locals>.<lambda>(g, t)
#     330 def tree_update_moment(updates, moments, decay, order):
#     331   """Compute the exponential moving average of the `order`-th moment."""
#     332   return jax.tree.map(
#     333       lambda g, t: (
# --> 334           (1 - decay) * (g**order) + decay * t if g is not None else None
#     335       ),
#     336       updates,
#     337       moments,
#     338       is_leaf=lambda x: x is None,
#     339   )
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:585, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     583 args = (other, self) if swap else (self, other)
#     584 if isinstance(other, _accepted_binop_types):
# --> 585   return binary_op(*args)
#     586 # Note: don't use isinstance here, because we don't want to raise for
#     587 # subclasses, e.g. NamedTuple objects that may override operators.
#     588 if type(other) in _rejected_binop_types:
#
# File /mnt/lustre/work/macke/mgloeckler90/miniconda3/envs/probjax/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:183, in ufunc.__call__(self, out, where, *args)
#     181   raise NotImplementedError(f"where argument of {self}")
#     182 call = self.__static_props['call'] or self._call_vectorized
# --> 183 return call(*args)
#
# KeyboardInterrupt:

# %%
nnx.update(model, params)

# %%
from probjax.utils.odeint import odeint



def sample(rng, numsteps=10):
    xt = jax.random.normal(rng, (28,28,1))
    ts = jnp.linspace(0, 1, numsteps + 1)
    for i in range(numsteps):
        t = ts[i]
        r = ts[i + 1]
        print(t,r)
        u = model(jnp.array([t]), xt, r=jnp.array([r]))
        xt = xt + u * (r-t)
    return xt

# %%
keys = jax.random.split(jax.random.key(0), (16,))

# %%
xs = jax.vmap(sample)(keys)
# Out:
# 0.0 0.1
# 0.1 0.2
# 0.2 0.3
# 0.3 0.4
# 0.4 0.5
# 0.5 0.6
# 0.6 0.7
# 0.7 0.8
# 0.8 0.90000004
# 0.90000004 1.0

# %%
xs.min(),xs.max()
# Out:
# (Array(-1.206, dtype=float32), Array(1.329, dtype=float32))

# %%
import matplotlib.pyplot as plt

img = xs.reshape(4, 4, 28, 28).transpose(0, 2, 1, 3).reshape(4*28, 4*28)
plt.figure(figsize=(10, 10))
plt.imshow(img, cmap="gray", vmin=-1, vmax=1)
plt.axis('off')
plt.show()
