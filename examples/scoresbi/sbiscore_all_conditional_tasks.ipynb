# %%
import jax 
import jax.numpy as jnp

from scoresbibm.src.tasks import get_task
from scoresbibm.src.methods.score_transformer import run_train_transformer_model

# %%
task = get_task("two_moons_all_cond")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 task = get_task("two_moons_all_cond")
#
# File /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/scoresbibm/src/tasks/__init__.py:17, in get_task(name, backend)
#      15     return SLCP(backend=backend)
#      16 elif name == "two_moons_all_cond":
# ---> 17     return TwoMoonsAllConditionalTask(backend=backend)
#      18 elif name == "slcp_all_cond":
#      19     return SLCPAllConditionalTask(backend=backend)
#
# File /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/scoresbibm/src/tasks/all_conditional_tasks.py:300, in TwoMoonsAllConditionalTask.__init__(self, backend)
#     299 def __init__(self, backend="jax") -> None:
# --> 300     super().__init__("two_moons", two_moons, backend=backend)
#
# File /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/scoresbibm/src/tasks/all_conditional_tasks.py:184, in AllConditionalBMTask.__init__(self, name, builder, backend)
#     183 def __init__(self, name, builder, backend="jax") -> None:
# --> 184     assert backend == "jax", "Only JAX backend is supported"
#     185     super().__init__(name, backend)
#     186     var_names, joint_sampler, potential_fn = builder()
#
# AssertionError: Only JAX backend is supported
