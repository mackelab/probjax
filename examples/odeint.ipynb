# %%
import jax
import jax.numpy as jnp

from probjax.utils.odeint import odeint, get_method_info, _odeint

A = jnp.array([[0., 1.], [-1., 0.]])
# Define the ODE
def f(t, x):
    return jnp.dot(A, x)

def true_f(t):
    Phi = jax.scipy.linalg.expm(A * t)
    return Phi@x0

# Define the initial condition
x0 = jnp.ones((2,))

# Define the time points to evaluate
t = jnp.linspace(0., 3., 100)

# Solve the ODE
x = odeint(f, x0, t, method="euler")

# Solve the ODE with dt
#with jax.disable_jit():
x2 = odeint(f, x0, t, method="rk4")

# Plot the solution
import matplotlib.pyplot as plt
plt.plot(t, x)
plt.plot(t, x2)
plt.plot(t, jax.vmap(true_f)(t), color="black")
plt.show()
plt.plot(t, jnp.abs(x - jax.vmap(true_f)(t)).sum(axis=-1), alpha=0.5)
plt.plot(t, jnp.abs(x2 - jax.vmap(true_f)(t)).sum(axis=-1), alpha=0.5)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
def test_f(t, x):
    x1, x2 = x
    return x1, x2*t

# %%
ys = odeint(test_f, (x0,x0), t, method="rk4")

# %%
def init(name):
    g = posterior_nn(name)

    def bulder(theta, xs):
        eta  =self.p_eta.sample(theta.shape[0])
        xs = torch.concat([xs, eta], axis=-1)
        return g(thetas, xs)
    
    self._build_neural_network = bulder

# %%
from functools import partial


ys = jax.vmap(partial(odeint, method="bosh3"), in_axes=(None, None, None, 0))(f,jnp.ones(1), t, jnp.linspace(0, 1, 100).reshape(100, 1))
_ = plt.plot(t, jnp.squeeze(ys).T)

# %%
# Keyword arguments

# %%
from probjax.core import inverse, inverse_and_logabsdet

def g(x0):
    ys = odeint(f, x0, t, method="bosh3")
    y1 = ys[-1]
    return y1

y1 = g(jnp.ones((1,)))
g_inv = inverse(g)

jaxpr = jax.make_jaxpr(g)(jnp.ones((1,)))

# %%
jaxpr.eqns[-2].invars
# Out:
# [b, e, h]

# %%
jaxpr
# Out:
# { lambda ; a:f32[1]. let
#     b:f32[1000,1] = custom_inverse_call_p[
#       forward_jaxpr={ lambda c:f32[1000] d:f32[3,3] e:f32[3] f:f32[3]; g:f32[1]. let
#           _:f32[] = max 0.0 1.1920928955078125e-07
#           h:f32[999] = dynamic_slice[slice_sizes=(999,)] c 1
#           i:f32[999] = dynamic_slice[slice_sizes=(999,)] c 0
#           j:f32[999] = sub h i
#           k:f32[1] = dynamic_slice[slice_sizes=(1,)] c 0
#           l:f32[] = squeeze[dimensions=(0,)] k
#           m:f32[1] = pow l g
#           n:f32[999] = dynamic_slice[slice_sizes=(999,)] c 1
#           _:f32[] _:f32[1] _:f32[1] o:f32[999,1] = scan[
#             jaxpr={ lambda ; p:f32[3,3] q:f32[3] r:f32[3] s:f32[] t:f32[1] u:f32[1]
#                 v:f32[] w:f32[]. let
#                 x:f32[1] y:f32[1] _:f32[3,1] = pjit[
#                   jaxpr={ lambda ; z:f32[] ba:f32[1] bb:f32[1] bc:f32[] bd:f32[3,3]
#                       be:f32[3] bf:f32[3]. let
#                       bg:f32[3,1] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(3, 1)
#                       ] 0.0
#                       bh:i32[1] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(1,)
#                       ] 0
#                       bi:f32[3,1] = scatter[
#                         dimension_numbers=ScatterDimensionNumbers(update_window_dims=(0,), inserted_window_dims=(0,), scatter_dims_to_operand_dims=(0,))
#                         indices_are_sorted=True
#                         mode=GatherScatterMode.FILL_OR_DROP
#                         unique_indices=True
#                         update_consts=()
#                         update_jaxpr={ lambda ; bj:f32[] bk:f32[]. let
#
#                           in (bk,) }
#                       ] bg bh bb
#                       _:i32[] bl:f32[3,1] = scan[
#                         jaxpr={ lambda ; bm:f32[3] bn:f32[] bo:f32[] bp:f32[3,3]
#                             bq:f32[1] br:i32[] bs:f32[3,1]. let
#                             bt:i32[] = add br 1
#                             bu:i32[] = sub br 1
#                             bv:bool[] = lt bu 0
#                             bw:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] bu
#                             bx:i32[] = add bw 3
#                             by:i32[] = select_n bv bu bx
#                             bz:f32[1] = dynamic_slice[slice_sizes=(1,)] bm by
#                             ca:f32[] = squeeze[dimensions=(0,)] bz
#                             cb:f32[] = mul bn ca
#                             cc:f32[] = add bo cb
#                             cd:i32[] = sub br 1
#                             ce:bool[] = lt cd 0
#                             cf:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] cd
#                             cg:i32[] = add cf 3
#                             ch:i32[] = select_n ce cd cg
#                             ci:bool[] = lt 0 0
#                             cj:i32[] = add 0 3
#                             ck:i32[] = select_n ci 0 cj
#                             cl:f32[1,3] = dynamic_slice[slice_sizes=(1, 3)] bp ch
#                               ck
#                             cm:f32[3] = squeeze[dimensions=(0,)] cl
#                             cn:f32[1] = dot_general[
#                               dimension_numbers=(([0], [0]), ([], []))
#                             ] cm bs
#                             co:f32[1] = mul bn cn
#                             cp:f32[1] = add bq co
#                             cq:f32[1] = pow cc cp
#                             cr:bool[] = lt br 0
#                             cs:i32[] = add br 3
#                             ct:i32[] = select_n cr br cs
#                             cu:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] ct
#                             cv:i32[1] = broadcast_in_dim[
#                               broadcast_dimensions=()
#                               shape=(1,)
#                             ] cu
#                             cw:f32[3,1] = scatter[
#                               dimension_numbers=ScatterDimensionNumbers(update_window_dims=(0,), inserted_window_dims=(0,), scatter_dims_to_operand_dims=(0,))
#                               indices_are_sorted=True
#                               mode=GatherScatterMode.FILL_OR_DROP
#                               unique_indices=True
#                               update_consts=()
#                               update_jaxpr={ lambda ; bj:f32[] bk:f32[]. let
#
#                                 in (bk,) }
#                             ] bs cv cq
#                           in (bt, cw) }
#                         length=2
#                         linear=(False, False, False, False, False, False, False)
#                         num_carry=2
#                         num_consts=5
#                         reverse=False
#                         unroll=1
#                       ] bf bc z bd ba 1 bi
#                       cx:f32[1] = dot_general[
#                         dimension_numbers=(([0], [0]), ([], []))
#                       ] be bl
#                       cy:f32[1] = mul bc cx
#                       cz:f32[1] = add cy ba
#                       da:bool[] = lt -1 0
#                       db:i32[] = add -1 3
#                       dc:i32[] = select_n da -1 db
#                       dd:bool[] = lt 0 0
#                       de:i32[] = add 0 1
#                       df:i32[] = select_n dd 0 de
#                       dg:f32[1,1] = dynamic_slice[slice_sizes=(1, 1)] bl dc df
#                       dh:f32[1] = squeeze[dimensions=(0,)] dg
#                     in (cz, dh, bl) }
#                   name=explicit_runge_kutta_step
#                 ] s t u w p q r
#               in (v, x, y, x) }
#             length=999
#             linear=(False, False, False, False, False, False, False, False)
#             num_carry=3
#             num_consts=3
#             reverse=False
#             unroll=1
#           ] d e f l g m n j
#           di:f32[1,1] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 1)] g
#           dj:f32[1000,1] = concatenate[dimension=0] di o
#         in (dj,) }
#       in_tree=PyTreeDef((*,))
#       inverse_jaxpr={ lambda dk:f32[1000] dl:f32[3,3] dm:f32[3] dn:f32[3]; do:f32[1]. let
#           dp:f32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0.0
#           dq:f32[2] = concatenate[dimension=0] do dp
#           dr:f32[1000] = rev[dimensions=(0,)] dk
#           _:f32[] = max 0.0 1.1920928955078125e-07
#           ds:f32[999] = dynamic_slice[slice_sizes=(999,)] dr 1
#           dt:f32[999] = dynamic_slice[slice_sizes=(999,)] dr 0
#           du:f32[999] = sub ds dt
#           dv:f32[1] = dynamic_slice[slice_sizes=(1,)] dr 0
#           dw:f32[] = squeeze[dimensions=(0,)] dv
#           dx:f32[1] = dynamic_slice[slice_sizes=(1,)] dq 0
#           dy:f32[1] = pow dw dx
#           dz:f32[1] = pow dw dx
#           ea:bool[] = eq dw 0.0
#           eb:f32[] = select_n ea dw 1.0
#           ec:f32[] = log eb
#           ed:f32[1] = mul ec dz
#           ee:i32[1,1] = iota[dimension=0 dtype=int32 shape=(1, 1)]
#           ef:i32[1,1] = add ee 0
#           eg:i32[1,1] = iota[dimension=1 dtype=int32 shape=(1, 1)]
#           eh:bool[1,1] = eq ef eg
#           ei:f32[1,1] = convert_element_type[new_dtype=float32 weak_type=False] eh
#           ej:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] ei
#           ek:f32[1,1] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 1)] ed
#           el:f32[1,1] = mul ej ek
#           em:f32[1,1] = slice[
#             limit_indices=(1, 1)
#             start_indices=(0, 0)
#             strides=None
#           ] el
#           en:f32[] = reduce_sum[axes=(0, 1)] em
#           eo:f32[1] = reshape[dimensions=None new_sizes=(1,)] en
#           ep:f32[2] = concatenate[dimension=0] dy eo
#           eq:f32[999] = dynamic_slice[slice_sizes=(999,)] dr 1
#           _:f32[] _:f32[2] _:f32[2] er:f32[999,2] = scan[
#             jaxpr={ lambda ; es:f32[3,3] et:f32[3] eu:f32[3] ev:f32[] ew:f32[2] ex:f32[2]
#                 ey:f32[] ez:f32[]. let
#                 fa:f32[2] fb:f32[2] _:f32[3,2] = pjit[
#                   jaxpr={ lambda ; fc:f32[] fd:f32[2] fe:f32[2] ff:f32[] fg:f32[3,3]
#                       fh:f32[3] fi:f32[3]. let
#                       fj:f32[3,2] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(3, 2)
#                       ] 0.0
#                       fk:i32[1] = broadcast_in_dim[
#                         broadcast_dimensions=()
#                         shape=(1,)
#                       ] 0
#                       fl:f32[3,2] = scatter[
#                         dimension_numbers=ScatterDimensionNumbers(update_window_dims=(0,), inserted_window_dims=(0,), scatter_dims_to_operand_dims=(0,))
#                         indices_are_sorted=True
#                         mode=GatherScatterMode.FILL_OR_DROP
#                         unique_indices=True
#                         update_consts=()
#                         update_jaxpr={ lambda ; bj:f32[] bk:f32[]. let
#
#                           in (bk,) }
#                       ] fj fk fe
#                       _:i32[] fm:f32[3,2] = scan[
#                         jaxpr={ lambda ; fn:f32[3] fo:f32[] fp:f32[] fq:f32[3,3]
#                             fr:f32[2] fs:i32[] ft:f32[3,2]. let
#                             fu:i32[] = add fs 1
#                             fv:i32[] = sub fs 1
#                             fw:bool[] = lt fv 0
#                             fx:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] fv
#                             fy:i32[] = add fx 3
#                             fz:i32[] = select_n fw fv fy
#                             ga:f32[1] = dynamic_slice[slice_sizes=(1,)] fn fz
#                             gb:f32[] = squeeze[dimensions=(0,)] ga
#                             gc:f32[] = mul fo gb
#                             gd:f32[] = add fp gc
#                             ge:i32[] = sub fs 1
#                             gf:bool[] = lt ge 0
#                             gg:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] ge
#                             gh:i32[] = add gg 3
#                             gi:i32[] = select_n gf ge gh
#                             gj:bool[] = lt 0 0
#                             gk:i32[] = add 0 3
#                             gl:i32[] = select_n gj 0 gk
#                             gm:f32[1,3] = dynamic_slice[slice_sizes=(1, 3)] fq gi
#                               gl
#                             gn:f32[3] = squeeze[dimensions=(0,)] gm
#                             go:f32[2] = dot_general[
#                               dimension_numbers=(([0], [0]), ([], []))
#                             ] gn ft
#                             gp:f32[2] = mul fo go
#                             gq:f32[2] = add fr gp
#                             gr:f32[1] = dynamic_slice[slice_sizes=(1,)] gq 0
#                             gs:f32[1] = pow gd gr
#                             gt:f32[1] = pow gd gr
#                             gu:bool[] = eq gd 0.0
#                             gv:f32[] = select_n gu gd 1.0
#                             gw:f32[] = log gv
#                             gx:f32[1] = mul gw gt
#                             gy:i32[1,1] = iota[
#                               dimension=0
#                               dtype=int32
#                               shape=(1, 1)
#                             ]
#                             gz:i32[1,1] = add gy 0
#                             ha:i32[1,1] = iota[
#                               dimension=1
#                               dtype=int32
#                               shape=(1, 1)
#                             ]
#                             hb:bool[1,1] = eq gz ha
#                             hc:f32[1,1] = convert_element_type[
#                               new_dtype=float32
#                               weak_type=False
#                             ] hb
#                             hd:f32[1,1] = slice[
#                               limit_indices=(1, 1)
#                               start_indices=(0, 0)
#                               strides=None
#                             ] hc
#                             he:f32[1,1] = broadcast_in_dim[
#                               broadcast_dimensions=(1,)
#                               shape=(1, 1)
#                             ] gx
#                             hf:f32[1,1] = mul hd he
#                             hg:f32[1,1] = slice[
#                               limit_indices=(1, 1)
#                               start_indices=(0, 0)
#                               strides=None
#                             ] hf
#                             hh:f32[] = reduce_sum[axes=(0, 1)] hg
#                             hi:f32[1] = reshape[dimensions=None new_sizes=(1,)] hh
#                             hj:f32[2] = concatenate[dimension=0] gs hi
#                             hk:bool[] = lt fs 0
#                             hl:i32[] = add fs 3
#                             hm:i32[] = select_n hk fs hl
#                             hn:i32[] = convert_element_type[
#                               new_dtype=int32
#                               weak_type=False
#                             ] hm
#                             ho:i32[1] = broadcast_in_dim[
#                               broadcast_dimensions=()
#                               shape=(1,)
#                             ] hn
#                             hp:f32[3,2] = scatter[
#                               dimension_numbers=ScatterDimensionNumbers(update_window_dims=(0,), inserted_window_dims=(0,), scatter_dims_to_operand_dims=(0,))
#                               indices_are_sorted=True
#                               mode=GatherScatterMode.FILL_OR_DROP
#                               unique_indices=True
#                               update_consts=()
#                               update_jaxpr={ lambda ; bj:f32[] bk:f32[]. let
#
#                                 in (bk,) }
#                             ] ft ho hj
#                           in (fu, hp) }
#                         length=2
#                         linear=(False, False, False, False, False, False, False)
#                         num_carry=2
#                         num_consts=5
#                         reverse=False
#                         unroll=1
#                       ] fi ff fc fg fd 1 fl
#                       hq:f32[2] = dot_general[
#                         dimension_numbers=(([0], [0]), ([], []))
#                       ] fh fm
#                       hr:f32[2] = mul ff hq
#                       hs:f32[2] = add hr fd
#                       ht:bool[] = lt -1 0
#                       hu:i32[] = add -1 3
#                       hv:i32[] = select_n ht -1 hu
#                       hw:bool[] = lt 0 0
#                       hx:i32[] = add 0 2
#                       hy:i32[] = select_n hw 0 hx
#                       hz:f32[1,2] = dynamic_slice[slice_sizes=(1, 2)] fm hv hy
#                       ia:f32[2] = squeeze[dimensions=(0,)] hz
#                     in (hs, ia, fm) }
#                   name=explicit_runge_kutta_step
#                 ] ev ew ex ez es et eu
#               in (ey, fa, fb, fa) }
#             length=999
#             linear=(False, False, False, False, False, False, False, False)
#             num_carry=3
#             num_consts=3
#             reverse=False
#             unroll=1
#           ] dl dm dn dw dq ep eq du
#           ib:f32[1,2] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 2)] dq
#           ic:f32[1000,2] = concatenate[dimension=0] ib er
#           id:bool[] = lt -1 0
#           ie:i32[] = add -1 1000
#           if:i32[] = select_n id -1 ie
#           ig:bool[] = lt 0 0
#           ih:i32[] = add 0 2
#           ii:i32[] = select_n ig 0 ih
#           ij:f32[1,1] = dynamic_slice[slice_sizes=(1, 1)] ic if ii
#           ik:f32[1] = squeeze[dimensions=(0,)] ij
#           il:bool[] = lt -1 0
#           im:i32[] = add -1 1000
#           in:i32[] = select_n il -1 im
#           io:bool[] = lt -1 0
#           ip:i32[] = add -1 2
#           iq:i32[] = select_n io -1 ip
#           ir:f32[1,1] = dynamic_slice[slice_sizes=(1, 1)] ic in iq
#           is:f32[] = squeeze[dimensions=(0, 1)] ir
#         in (ik, is) }
#     ] a
#     it:bool[] = lt -1 0
#     iu:i32[] = add -1 1000
#     iv:i32[] = select_n it -1 iu
#     iw:bool[] = lt 0 0
#     ix:i32[] = add 0 1
#     iy:i32[] = select_n iw 0 ix
#     iz:f32[1,1] = dynamic_slice[slice_sizes=(1, 1)] b iv iy
#     ja:f32[1] = squeeze[dimensions=(0,)] iz
#   in (ja,) }

# %%
jax.lax.dynamic_slice(jnp.arange(0, 10), (2,), (4,))
# Out:
# Array([2, 3, 4, 5], dtype=int32)

# %%
f(x0, t[0])
# Out:
# Array([-1., -1.], dtype=float32)

# %%
# def _inv_logdet_odeint(drift, y0, ts, *args, **kwargs):
#     drift_jac = jax.jacobian(drift, argnums=1)

#     def aug_drift(t, x, *args):
#         print("X",x.shape)
#         x = x[:-1]
#         x_new = drift(t, x, *args)
#         jac = drift_jac(t, x, *args)
#         print(jac.shape)
#         if jac.ndim > 2:
#             logdet_new = jnp.diagonal(jac, axis1=-2, axis2=-1).sum().reshape((1,))
#         else:
#             logdet_new = jac.sum().reshape((1,))

#         return jnp.concatenate([x_new, logdet_new])

#     y0_extended = jnp.concatenate([y0, jnp.zeros((1,))])
#     print(y0_extended.shape)
#     ys_extended = odeint(aug_drift, y0_extended, ts, *args, **kwargs)
#     ys = ys_extended[:, :-1]
#     logdet = ys_extended[-1, -1]

#     return ys, logdet

# with jax.disable_jit():
#     _inv_logdet_odeint(f, x0, t, method="euler")

# %%
ys = odeint(f, x0*1e-20, t[::-1], method="heun_euler")

plt.plot(t, ys[::-1])

# ys = odeint(lambda x,t : f(-x, t), x0*1e-20, t, method="rk3(2)")
# plt.plot(t, ys)

# %%
from jax import lax
from typing import Callable, Tuple, Union
from jax import Array

def explicit_stochastic_runge_kutta_step(
    drift: Callable,
    diffusion: Callable,
    t0: Array,
    y0: Array,
    f0: Array,
    g0: Array,
    dt: Array,
    dWt: Array,
    dWtdWs: Array,
    c0: Array,
    c1: Array,
    A0: Array,
    A1: Array,
    B0: Array,
    B1: Array,
    b_sol: Array,
    gamma0: Array,
    gamma1: Array,
    b_error: Array,
    order: int,
):
    def body_fun(i, k1, k2):
        ti1 = t0 + dt * c0[i - 1]
        ti2 = t0 + dt * c1[i - 1]

        yi1 = y0 + dt.astype(f0.dtype) * jnp.dot(A0[i - 1, :], k1) + dWt * jnp.dot(B1[i - 1, :], k2)
        yi2 = y0 + dt.astype(f0.dtype) * jnp.dot(A1[i - 1, :], k1) + jnp.sqrt(dt) * jnp.dot(B1[i - 1, :], k2)

        ft = drift(yi1, ti1)
        gt = diffusion(yi2, ti2)
        return k1.at[i, :].set(ft), k2.at[i, :].set(gt)

    k1 = jnp.zeros((order, f0.shape[0]), f0.dtype).at[0, :].set(f0)
    k2 = jnp.zeros((order, f0.shape[0]), f0.dtype).at[0, :].set(f0)
    k1,k2 = lax.fori_loop(1, order, body_fun, k1, k2)

    y1 = y0 + dt.astype(f0.dtype) * jnp.dot(b_sol, k1) + dWt * jnp.dot(gamma0, k2) + dWtdWs * jnp.dot(gamma1, k2)
    f1 = k1[-1]
    g1 = k2[-1]

    if b_error is None:
        y1_error = None
    else:
        raise NotImplementedError

    return y1, f1,g1, (y1_error, k1,k2)

# %%
# odeint for all methods
from probjax.utils.odeint import odeint, get_methods

METHODS = get_methods()

for m in METHODS:
    print(m)
    #with jax.disable_jit():
    x = odeint(f, x0, t, method=m)
    
    plt.plot(t, x, label=m, alpha=0.5)
    plt.plot(jnp.linspace(0, 10, 10000), odeint(f, x0, jnp.linspace(0, 10, 10000), method="rk4"), color="black", lw=2, linestyle="--")
    plt.show()



plt.legend(METHODS + ["True"])
# Out:
# euler
# heun
# heun_euler
# midpoint
# ralston
# rk3
# rk3(2)
# bosh3
# heun3
# vanderhouwen
# ralston3
# ssprk3
# rk4
# rk4(5)
# 3/8
# ralston4
# rk5(4)
# dopri5
# implicit_euler
# implicit_midpoint
# implicit_trapezoidal
# implicit_crank_nicolson
# gauss_legendre

# %%
def f(x):
    return x**2 - 2

# %%
jnp.finfo(jnp.float32).eps
# Out:
# 1.1920929e-07

# %%
from jax import lax
from functools import partial

METHODS = {}


c0 = jnp.array([0., 1.])
A0 = jnp.array([[0., 0.], [1., 0.]])
b_sol = jnp.array([0.5, 0.5])
b_error = jnp.array([1., 0.])

@partial(jax.jit, static_argnums=(0,))
def runge_kutta_step(func, y0, f0, t0, dt, c, A, b_sol, b_error, order=2):
  # Dopri5 Butcher tableaux

  def body_fun(i, k):
    ti = t0 + dt * c[i-1]
    yi = y0 + dt.astype(f0.dtype) * jnp.dot(A[i-1, :], k)
    ft = func(yi, ti)
    return k.at[i, :].set(ft)

  k = jnp.zeros((order, f0.shape[0]), f0.dtype).at[0, :].set(f0)
  k = lax.fori_loop(1, order, body_fun, k)

  y1 = dt.astype(f0.dtype) * jnp.dot(b_sol, k) + y0
  y1_error = dt.astype(f0.dtype) * jnp.dot(b_error, k)
  f1 = k[-1]
  return y1, f1, y1_error, k

# %%
jnp.linalg.is_tril(A0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> jnp.linalg.is_tril(A)
#
# AttributeError: module 'jax.numpy.linalg' has no attribute 'is_tril'

# %%
# %%timeit
runge_kutta_step(f, jnp.array([1.]), jnp.array([1.]), jnp.array([0.]), jnp.array([1.]), alpha, beta, c_sol, c_error)
# Out:
# 424 µs ± 16.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
@partial(jax.jit, static_argnums=(0,))
def _heun_step(_f, t0, y0, dt):
    half_dt = dt / 2
    k1 = _f(t0, y0)
    k2 = _f(t0 + half_dt, y0 + half_dt * k1)
    return y0 + (k1 + k2)/2 * dt

# %%
# %%timeit
_heun_step(f, jnp.array([0.]), jnp.array([1.]), jnp.array([1.]))
# Out:
# 293 µs ± 23.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
def newton_raphson(f, x0, tol=1e-6, max_iter=50):
    """
    Newton-Raphson root-finding algorithm for a vector-valued function.
    
    Args:
    - f: A function that takes a vector x and returns a vector of the same shape.
    - x0: Initial guess for the root.
    - tol: Tolerance for stopping criterion (default: 1e-6).
    - max_iter: Maximum number of iterations (default: 100).
    
    Returns:
    - x: The estimated root of the function.
    """
    x = x0

    f_jax = jax.jacobian(f)

    def scan_fn(carry, i):
        tol_reached, x = carry

        def true_fn(x):
            return x, jnp.inf

        def false_fn(x):
            y = f(x)
            J = f_jax(x)
            delta_x = jax.scipy.linalg.solve(J, -y)
            x = x + delta_x
            return x, jnp.linalg.norm(delta_x)
        
        
        x, delta_x = jax.lax.cond(tol_reached, true_fn, false_fn, x)
        tol_reached = delta_x < tol
        return (tol_reached, x), x
      
    
    tol_reached = False
    _, x = jax.lax.scan(scan_fn, (tol_reached, x), jnp.arange(max_iter))
    return x[-1]

newton_raphson(f, jnp.array([100.]))
# Out:
# Array([1.414], dtype=float32)

# %%
from probjax.utils.interpolation import linear_interpolation

jax.vmap(linear_interpolation(t, x))(jnp.array([0.5, 0.75])).shape
# Out:
# (2, 1)

# %%
from functools import partial
from typing import Optional, Tuple, Union
from jax import Array 
from jaxtyping import Float


jax.jit
def _generate_grid(ts: jnp.ndarray, dt_max: Optional[float] = None):
    """Generate a grid of time points that satisfy the minimum dt

    Args:
        ts (jnp.ndarray): Time points.
        max_dt (Optional[float], optional): Maximum dt. Defaults to None.

    Returns:
        jnp.ndarray: Grid of time points.
    """
    dts = ts[1:] - ts[:-1]
    dts_expension = jnp.ceil(dts / dt_max)

    def scan_fn(t_prev, dt):
        def true_fn(dt):
            return t_prev + dt
        
        def false_fn(dt):
            
            def cond_fn(t):
                return t < t_prev + dt
            
            def body_fn(t):
                return t + dt
            
            return jax.lax.while_loop(cond_fn, body_fn, t_prev)
        return t, grid
    
    _, grid = jax.lax.scan(scan_fn, (ts[0],), dts)

# %%
dt_max = 0.1
ts = jnp.array([0.0, 0.1, 0.35,0.5])
dts  = ts[1:] - ts[:-1]

dts_extension = jnp.ceil(dts/dt_max)

dts_extension
# Out:
# Array([1., 3., 2.], dtype=float32)

# %%
@jax.jit 
def f(ts):
    T_max = ts[-1]
    T_min = ts[0]
    ts = _generate_grid(ts, T_max, T_min, max_dt=0.1)

# %%
f(t)
# Out:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> f(t)
#
#     [... skipping hidden 12 frame]
#
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> T_max = ts[-1]
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> T_min = ts[0]
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> ts = _generate_grid(ts, T_max, T_min, max_dt=0.1)
#
#     [... skipping hidden 12 frame]
#
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     return ts, None
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> else:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>     ts_max_dt = jnp.linspace(ts[0], ts[1], int((T_max - T_min) / max_dt))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     index = jnp.searchsorted(ts_max_dt, ts)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/odeint.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>     return jnp.insert(ts_max_dt, index, ts), index
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:1345, in concretization_function_error.<locals>.error(self, arg)
#    1344 def error(self, arg):
# -> 1345   raise ConcretizationTypeError(arg, fname_context)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=2/0)>
# The problem arose with the `int` function. If trying to convert the data type of a value, try using `x.astype(int)` or `jnp.array(x, int)` instead.
# The error occurred while tracing the function _generate_grid at /tmp/ipykernel_10811/4238015521.py:7 for jit. This value became a tracer due to JAX operations on these lines:
#
#   operation a:f32[] = sub b c
#     from line /tmp/ipykernel_10811/4238015521.py:21 (_generate_grid)
#
#   operation a:f32[] = convert_element_type[new_dtype=float32 weak_type=False] b
#     from line /tmp/ipykernel_10811/4238015521.py:21 (_generate_grid)
#
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.ConcretizationTypeError

# %%
ts.shape
# Out:
# (1100,)

# %%
ts[:100]
# Out:
# Array([0.   , 0.   , 0.   , 0.   , 0.   , 0.   , 0.001, 0.001, 0.001,
#        0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.002, 0.002,
#        0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.003,
#        0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.004, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005,
#        0.005, 0.006, 0.006, 0.006, 0.006, 0.006, 0.006, 0.006, 0.006,
#        0.006, 0.006, 0.007, 0.007, 0.007, 0.007, 0.007, 0.007, 0.007,
#        0.007, 0.007, 0.007, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008,
#        0.008, 0.008, 0.008, 0.008, 0.009, 0.009, 0.009, 0.009, 0.009,
#        0.009, 0.009, 0.009, 0.009, 0.009, 0.01 , 0.01 , 0.01 , 0.01 ,
#        0.01 ], dtype=float32)
