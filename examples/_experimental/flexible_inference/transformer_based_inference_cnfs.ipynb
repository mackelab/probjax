# %%
# Transformers example -> Reverseing sequence of numbers

# %%
import haiku as hk
import jax
import jax.numpy as jnp
import jax.random as jrandom
import matplotlib.pyplot as plt
import numpy as np
import optax

from probjax.nn.transformers import Transformer
from sbi.analysis import pairplot
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
jax.devices()
# Out:
# [CpuDevice(id=0)]

# %%
def generate_data(key, n):
    key1, key2, key3 = jrandom.split(key,3)
    theta1 = jrandom.normal(key1, (n, 1))  * 3
    x1 = 2*jnp.sin(theta1) + jrandom.normal(key2, (n, 1)) * 0.5
    #x3 = theta1 + jrandom.normal(key2, (n, 1)) * 0.5
    # x2 = 2*jnp.sin(theta1) + jrandom.normal(key3, (n, 1)) * 0.1
    # x2 = .3*theta1 + 10 + jrandom.normal(key, (n, 1))
    # x3 = jnp.sin(theta1) + jrandom.normal(key, (n, 1))
    # x4 = jnp.cos(theta1) + jrandom.normal(key, (n, 1))
    return jnp.concatenate([theta1,x1], axis=1).reshape(n, -1, 1)


data = generate_data(jrandom.PRNGKey(1), 10000)
mean = data.mean(axis=0)
std = data.std(axis=0)
T_max = data.shape[1]

node_ids = jnp.arange(T_max)

# %%
pairplot(np.array(data[:, :, 0]), limits=[[-10, 10], [-10, 10], [-10, 10]])
# Out:
# (<Figure size 1000x1000 with 4 Axes>,
#  array([[<Axes: xlabel='dim 1'>, <Axes: >],
#         [<Axes: >, <Axes: xlabel='dim 2'>]], dtype=object))

# %%
key = jrandom.PRNGKey(0)

# %%
from probjax.nn.helpers import TimeEmbedding

# %%
def model(t,x , node_ids, condition_mask):
    dim = 100

    #x = (x - mean)/std

    x = x.reshape(x.shape[0], -1)
    t = t.reshape(-1,1)

    embedding_net = hk.Linear(dim)
    embedding_time = TimeEmbedding(dim)



    model = hk.nets.MLP([200, 200, 200, T_max])

    value_embed = embedding_net(x)
    time_embed = embedding_time(t)

    x_encoded = jnp.concatenate([value_embed, time_embed], axis=1)
    #x_encoded = value_embed + time_embed

    h = model(x_encoded)

    return h.reshape(h.shape[0], T_max, 1)

# %%
def model(t, x, node_ids, condition_mask):
    condition_mask = condition_mask.astype(int)
    # Embed values and conditions
    dim = 200
    embedding_net = hk.Linear(dim)
    embedding_id_nets = hk.Embed(T_max, dim)
    embedding_time = TimeEmbedding(dim)
    embedding_condition_mask = hk.Embed(2**T_max, dim)

    model = Transformer(num_heads=2, num_layers=5, attn_size=dim, dropout_rate=0.0, widening_factor=2)


    value_embeddings = embedding_net(x)
    id_embeddings = embedding_id_nets(node_ids)
    time_embeddings = embedding_time(t.reshape(-1,1,1))
    condition_embedding = embedding_condition_mask(condition_mask)

    x_encoded = value_embeddings + id_embeddings + time_embeddings + condition_embedding



    # Encode
    h = model(x_encoded)

    # Decode
    h_t = jnp.concatenate([time_embeddings, h], axis=-1)
    out = hk.nets.MLP([dim, dim, 1])(h_t)

    out = out * (1-condition_mask.reshape(-1,T_max,1))
    return out

# %%
def model(t, x, node_ids, condition_mask):
    condition_mask = condition_mask.astype(int)
    # Embed values and conditions
    dim = 200
    _dim = dim // 4
    embedding_net = hk.nets.MLP([dim, _dim])
    embedding_id_nets = hk.Embed(T_max, _dim)
    embedding_time = hk.Sequential([TimeEmbedding(_dim), hk.nets.MLP([_dim, _dim])])
    embedding_condition_mask = hk.Embed(2**T_max, _dim)

    # Positional embedding

    model = Transformer(num_heads=2, num_layers=4, attn_size=dim, dropout_rate=0.0, widening_factor=2)


    value_embeddings = embedding_net(x)
    id_embeddings = embedding_id_nets(node_ids)
    id_embeddings = jnp.broadcast_to(id_embeddings, value_embeddings.shape)
    time_embeddings = embedding_time(t.reshape(-1,1,1))
    time_embeddings = jnp.broadcast_to(time_embeddings, value_embeddings.shape)
    condition_embedding = embedding_condition_mask(condition_mask)
    condition_embedding = jnp.broadcast_to(condition_embedding, value_embeddings.shape)



    x_encoded = jnp.concatenate([value_embeddings, id_embeddings, time_embeddings, condition_embedding], axis=-1)

    #x_encoded = embedding_positional(x_encoded)


    # Encode
    h = model(x_encoded)

    # Decode
    h_t = jnp.concatenate([time_embeddings, h], axis=-1)
    out = hk.nets.MLP([dim, dim, 1])(h_t)

    out = out * (1-condition_mask.reshape(-1,len(node_ids),1))
    return out

# %%
init, model_fn = hk.transform(model)
params = init(key, jnp.ones(data.shape[0]), data, node_ids, jnp.zeros_like(node_ids))

# %%
times = jax.random.uniform(key, (data.shape[0], 1, 1), minval=1e-6, maxval=1.0)
out = model_fn(params, key, times, data, node_ids, jnp.zeros_like(node_ids))

# %%
T = 1.
T_min = 1e-6
beta_min = 0.1
beta_max = 10.

def beta(t):
    return beta_min + t * (beta_max - beta_min)

def drift_fn(x, t):
    return -0.5 * (beta(t)) * x

def diffusion_fn(x, t):
    # This migh requrire a square root
    return jnp.sqrt(beta(t)) * jnp.ones_like(x)

def marginal_mean(x0, t):
    phi = jnp.exp(-0.25 * t**2 * (beta_max - beta_min) - 0.5*t * beta_min)
    return phi * x0

def marginal_std(x0, t):
    phi = jnp.exp(-0.5 * t**2 * (beta_max - beta_min) - t * beta_min)
    return jnp.sqrt(1 - 1 * phi)

def sbd_forward(key, x0, t):
    noise = jax.random.normal(key, x0.shape)
    std = marginal_std(x0, t)
    x_noised = marginal_mean(x0, t) + std * noise
    return x_noised

log_prob_fn = lambda x, t, x0: jax.scipy.stats.norm.logpdf(x, marginal_mean(x0, t), marginal_std(x0, t)).sum()
score_fn = jax.grad(log_prob_fn)

# %%
optimizer = optax.adam(1e-2)
opt_state = optimizer.init(params)


def loss_fn(params, key, batch_size= 128):

    rng_model, rng_time, rng_sample, rng_data, rng_permute_ids, rng_condition = jax.random.split(key, 6)

    # Generate data
    times = jax.random.uniform(rng_time, (batch_size, 1, 1), minval=T_min, maxval=1.0)
    batch_xs = generate_data(rng_data, batch_size) # n, T_max, 1

    # Permute sequence -> randomly permute the sequence of data to promote node identification
    ids = jax.random.choice(rng_permute_ids,jnp.array([node_ids, node_ids[::-1]]), shape=(), axis=0)
    batch_xs = batch_xs[:, ids, :]

    # Condition mask -> randomly condition on some data -> Sample more frequently no condition
    condition_mask = jax.random.choice(rng_condition, jnp.array([[0,0], [1,0], [0,1]]), shape=(batch_size, ), p=jnp.array([0.5, 0.25, 0.25]), axis=0)
    condition_mask = condition_mask[..., None]


    # Forward diffusion
    batch_noisy_xs = sbd_forward(rng_sample, batch_xs, times)
    batch_noisy_xs = batch_noisy_xs * (1-condition_mask) + batch_xs * condition_mask # Condition on the data

    score_pred = model_fn(params, rng_model, times, batch_noisy_xs, ids, condition_mask[...,0])
    score_target = score_fn(batch_noisy_xs, times, batch_xs)
    # Weighting function
    # Seems to be important here
    lam = beta(times)
    # Loss

    loss = jnp.mean(jnp.sum((1- condition_mask)*lam*(score_pred - score_target) ** 2, axis=-2))
    return loss


@jax.jit
def update(params, rng, opt_state):
    loss, grads = jax.value_and_grad(loss_fn)(params, rng)
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return loss, params, opt_state

# %%
optimizer = optax.adam(1e-3)
opt_state = optimizer.init(params)

# %%
for _ in range(10):
    l = 0
    for i in range(500):
        key = jrandom.PRNGKey(i)
        loss, params, opt_state = update(params, key, opt_state)
        l += loss / 2000
    print(l)

# %%
# Check vector field
x, y = jnp.meshgrid(jnp.arange(-12, 12, 0.5), jnp.arange(-4, 4, 0.3))
pos = jnp.dstack((x, y)).reshape(-1, T_max, 1)
vs = model_fn(params, key, jnp.ones((pos.shape[0],1, 1)) * 0.1, pos, node_ids, jnp.zeros_like(node_ids))

plt.quiver(pos[:, 0], pos[:, 1], vs[:, 0], vs[:, 1], scale=100)

# %%
condition_mask = jnp.array([0,0])
condition_value = jnp.array([0., 0])

def drift_backward(t, x, node_ids=node_ids, condition_mask=condition_mask):
    #t = T - t
    score = model_fn(params, key, t.reshape(-1, 1, 1), x.reshape(-1, len(node_ids), 1), node_ids,condition_mask[:len(node_ids)])
    score = score.reshape(x.shape)

    f =  drift_fn(x, t) - diffusion_fn(x, t)**2 * score
    f = f * (1-condition_mask)
    return f

def diffusion_backward(t,x, node_ids=node_ids,condition_mask=condition_mask):
    #t = T - t
    b =  diffusion_fn(x, t)
    b = b * (1-condition_mask[:len(node_ids)])
    return b

# %%
from probjax.utils.sdeint import sdeint

# %%
noise = jax.vmap(lambda *args: sdeint(*args, noise_type="diagonal"), in_axes= (0, None, None, 0, None), out_axes=0)(jrandom.split(key, (1000,)),lambda t, x: drift_fn(x, t), lambda t, x: diffusion_fn(x,t), data[:1000, :, 0], jnp.linspace(T_min, 1., 200))

# Condition on 0 -> sin(0) = 0!
noise = noise * (1-condition_mask) + condition_value * condition_mask

ys = jax.vmap(lambda *args: sdeint(*args, noise_type="diagonal"), in_axes= (0, None, None, 0, None), out_axes=0)(jrandom.split(key, (1000,)), drift_backward, diffusion_backward, noise[:,-1], jnp.linspace(1.,T_min, 200))

# %%
fig, ax = plt.subplots(T_max)
for i in range(T_max):
    _ = ax[i].plot(noise[:, :, i].T, color=f"C{i}", alpha=0.01)
    ax[i].set_ylim(-10, 10)
    ax[i].set_ylabel("Variable {}".format(i))

# %%
fig, ax = plt.subplots(T_max)
for i in range(T_max):
    _ = ax[i].plot(ys[:, :, i].T, color=f"C{i}", alpha=0.01)
    ax[i].set_ylim(-10, 10)
    ax[i].set_ylabel("Variable {}".format(i))

# %%
def sample_fn(key, shape, node_ids=node_ids, time_steps=500, condition_mask=jnp.zeros((T_max,), dtype=int), condition_value=jnp.zeros((T_max,))):
    condition_mask = condition_mask[:len(node_ids)]
    key1, key2 = jrandom.split(key, 2)
    x_T = jax.random.normal(key1, shape + (len(node_ids),)) * marginal_std(jnp.zeros(shape), 1.)
    x_T = x_T * (1-condition_mask) + condition_value * condition_mask
    keys = jrandom.split(key2, shape)
    ys = jax.vmap(lambda *args: sdeint(*args, noise_type="diagonal"), in_axes= (0, None, None, 0, None), out_axes=0)(keys, lambda t, x: drift_backward(t, x, node_ids, condition_mask), lambda t, x: diffusion_backward(t, x, node_ids, condition_mask), x_T, jnp.linspace(1.,T_min, time_steps))
    return ys

# %%
samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=node_ids, condition_mask=condition_mask, condition_value=condition_value)
pairplot([np.array(data[:1000,:,0]),np.array(samples[...,-1, :])], upper="scatter")
# Out:
# (<Figure size 1000x1000 with 4 Axes>,
#  array([[<Axes: xlabel='dim 1'>, <Axes: >],
#         [<Axes: >, <Axes: xlabel='dim 2'>]], dtype=object))

# %%
samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=node_ids, condition_mask=jnp.array([0,1]), condition_value=jnp.array([0., 2.]))
pairplot([np.array(data[:1000,:,0]),np.array(samples[...,-1, :])], upper="scatter")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=node_ids, condition_mask=jnp.array([0,1]), condition_value=jnp.array([0., 2.]))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> pairplot([np.array(data[:1000,:,0]),np.array(samples[...,-1, :])], upper="scatter")
#
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb Cell 25 line 7
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> x_T = x_T * (1-condition_mask) + condition_value * condition_mask
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> keys = jrandom.split(key2, shape)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> ys = jax.vmap(lambda *args: sdeint(*args, noise_type="diagonal"), in_axes= (0, None, None, 0, None), out_axes=0)(keys, lambda t, x: drift_backward(t, x, node_ids, condition_mask), lambda t, x: diffusion_backward(t, x, node_ids, condition_mask), x_T, jnp.linspace(1.,T_min, time_steps))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> return ys
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/api.py:1258, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1255 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1256 axis_size_ = (axis_size if axis_size is not None else
#    1257               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1258 out_flat = batching.batch(
#    1259     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1260     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1261     spmd_axis_name=spmd_axis_name
#    1262 ).call_wrapped(*args_flat)
#    1263 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/linear_util.py:188, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 gen = gen_static_args = out_store = None
#     187 try:
# --> 188   ans = self.f(*args, **dict(self.params, **kwargs))
#     189 except:
#     190   # Some transformations yield from inside context managers, so we have to
#     191   # interrupt them before reraising the exception. Otherwise they will only
#     192   # get garbage-collected at some later time, running their cleanup tasks
#     193   # only after this exception is handled, which can corrupt the global
#     194   # state.
#     195   while stack:
#
# /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb Cell 25 line 7
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> x_T = x_T * (1-condition_mask) + condition_value * condition_mask
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> keys = jrandom.split(key2, shape)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> ys = jax.vmap(lambda *args: sdeint(*args, noise_type="diagonal"), in_axes= (0, None, None, 0, None), out_axes=0)(keys, lambda t, x: drift_backward(t, x, node_ids, condition_mask), lambda t, x: diffusion_backward(t, x, node_ids, condition_mask), x_T, jnp.linspace(1.,T_min, time_steps))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/examples/transformer_based_inference_diffusion.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> return ys
#
# File /mnt/c/Users/manug/OneDrive/Uni/PHD/probjax/probjax/utils/sdeint.py:580, in sdeint(key, drift, diffusion, y0, ts, method, sde_type, noise_type, return_brownian, dt, rtol, atol, mxstep, dtmin, dtmax, *args)
#     577 else:
#     578     iterated_integral_fn = None
# --> 580 return _sdeint_on_grid(
#     581     key,
#     582     _f,
#     583     _g,
#     584     y0,
#     585     ts,
#     586     step_fn,
#     587     sde_type,
#     588     noise_type,
#     589     iterated_integral_fn=iterated_integral_fn,
#     590     return_brownian=return_brownian,
#     591 )
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:253, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     251 @api_boundary
#     252 def cache_miss(*args, **kwargs):
# --> 253   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     254       fun, infer_params_fn, *args, **kwargs)
#     255   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     256   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:166, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     164   dispatch.check_arg(arg)
#     165 try:
# --> 166   out_flat = pjit_p.bind(*args_flat, **params)
#     167 except pxla.DeviceAssignmentMismatchError as e:
#     168   fails, = e.args
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:2596, in AxisPrimitive.bind(self, *args, **params)
#    2592 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2593                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2594 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595              else axis_main.with_cur_sublevel())
# -> 2596 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:389, in Primitive.bind_with_trace(self, trace, args, params)
#     388 def bind_with_trace(self, trace, args, params):
# --> 389   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:431, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     429   frame = self.get_frame(vals_in, dims_in)
#     430   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 431   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     432 src = source_info_util.current()
#     433 if primitive.multiple_results:
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:1431, in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1423 in_shardings = tuple(
#    1424     _pjit_batcher_for_sharding(i, axis_in, new_parts, mesh, aval.ndim)
#    1425     if axis_in is not None else i
#    1426     for axis_in, i, aval in zip(dims_in, in_shardings, new_jaxpr.in_avals))
#    1427 out_shardings = tuple(
#    1428     _pjit_batcher_for_sharding(o, axis_out, new_parts, mesh, aval.ndim)
#    1429     if axis_out is not None else o
#    1430     for axis_out, o, aval in zip(axes_out, out_shardings, new_jaxpr.out_avals))
# -> 1431 vals_out = pjit_p.bind(
#    1432   *vals_in,
#    1433   jaxpr=new_jaxpr,
#    1434   in_shardings=in_shardings,
#    1435   out_shardings=out_shardings,
#    1436   resource_env=resource_env,
#    1437   donated_invars=donated_invars,
#    1438   name=name,
#    1439   keep_unused=keep_unused,
#    1440   inline=inline)
#    1441 resolved_axes_out = batching.resolve_ragged_axes_against_inputs_outputs(
#    1442     vals_in, vals_out, axes_out)
#    1443 return vals_out, resolved_axes_out
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:2596, in AxisPrimitive.bind(self, *args, **params)
#    2592 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2593                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2594 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2595              else axis_main.with_cur_sublevel())
# -> 2596 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:389, in Primitive.bind_with_trace(self, trace, args, params)
#     388 def bind_with_trace(self, trace, args, params):
# --> 389   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     390   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/core.py:821, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     820 def process_primitive(self, primitive, tracers, params):
# --> 821   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:1209, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1206 has_explicit_sharding = _pjit_explicit_sharding(
#    1207     in_shardings, out_shardings, None, None)
#    1208 if xla_extension_version >= 169:
# -> 1209   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1210                       tree_util.default_registry,
#    1211                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1212 else:
#    1213   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1214                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:1192, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1191 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1192   out_flat, compiled = _pjit_call_impl_python(
#    1193       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1194       out_shardings=out_shardings, resource_env=resource_env,
#    1195       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1196       inline=inline)
#    1197   fastpath_data = _get_fastpath_data(
#    1198       compiled, tree_structure(out_flat), args, out_flat)
#    1199   return out_flat, fastpath_data
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/pjit.py:1148, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1142   distributed_debug_log(("Running pjit'd function", name),
#    1143                         ("in_shardings", in_shardings),
#    1144                         ("out_shardings", out_shardings),
#    1145                         ("abstract args", map(xla.abstractify, args)),
#    1146                         ("fingerprint", fingerprint))
#    1147 try:
# -> 1148   return compiled.unsafe_call(*args), compiled
#    1149 except FloatingPointError:
#    1150   assert config.jax_debug_nans or config.jax_debug_infs  # compiled_fun can only raise in this case
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/rvtorch/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1229, in ExecuteReplicated.__call__(self, *args)
#    1224   self._handle_token_bufs(
#    1225       results.disassemble_prefix_into_single_device_arrays(
#    1226           len(self.ordered_effects)),
#    1227       results.consume_token())
#    1228 else:
# -> 1229   results = self.xla_executable.execute_sharded(input_bufs)
#    1230 if dispatch.needs_check_special():
#    1231   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:

# %%
samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=node_ids, condition_mask=jnp.array([0,1]), condition_value=jnp.array([0., 0.]))
pairplot([np.array(data[:1000,:,0]),np.array(samples[...,-1, :])], upper="scatter")
# Out:
# 2
# (<Figure size 1000x1000 with 4 Axes>,
#  array([[<Axes: xlabel='dim 1'>, <Axes: >],
#         [<Axes: >, <Axes: xlabel='dim 2'>]], dtype=object))

# %%
samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=node_ids, condition_mask=jnp.array([1,0]), condition_value=jnp.array([0., 2.]))
pairplot([np.array(data[:1000,:,0]),np.array(samples[...,-1, :])], upper="scatter")
# Out:
# 2
# (<Figure size 1000x1000 with 4 Axes>,
#  array([[<Axes: xlabel='dim 1'>, <Axes: >],
#         [<Axes: >, <Axes: xlabel='dim 2'>]], dtype=object))

# %%
import numpy as np

from sbi.analysis import pairplot

condition_mask = jnp.array([0,0])

samples = sample_fn(jrandom.PRNGKey(0), (1000, ), node_ids=jnp.array([1]))
_ = plt.hist(np.array(samples[...,-1, 1]).flatten(), bins=100)
# Out:
# 2
