# %%
from probjax.distributions.constraints import real, positive, negative, unit_interval, integer


sorted([positive, real, negative, unit_interval, integer])
# Out:
# [positive, negative, unitinterval, integer, real]

# %%
unit_interval
# Out:
# interval
