# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import scipy
import scipy.stats as stats

# %%
p = stats.norm(0.)

# %%
p.logpdf(1000)
# Out:
# np.float64(-500000.9189385332)

# %%
import jax
import jax.numpy as jnp

# %%
jax.scipy.stats.norm.logcdf
# Out:
# <function jax._src.scipy.stats.norm.logcdf(x: Union[jax.Array, numpy.ndarray, numpy.bool, numpy.number, bool, int, float, complex], loc: Union[jax.Array, numpy.ndarray, numpy.bool, numpy.number, bool, int, float, complex] = 0, scale: Union[jax.Array, numpy.ndarray, numpy.bool, numpy.number, bool, int, float, complex] = 1) -> jax.Array>

# %%
from probjax.stats import norm, gamma, beta, expon, laplace, uniform
norm(0.,jnp.array([2., 3.])).rvs(jax.random.PRNGKey(0))
# Out:
# Array([3.2452843, 6.075794 ], dtype=float32)

# %%
beta(1., jnp.array([2., 3.])).rvs(jax.random.PRNGKey(0))
# Out:
# Array([0.13298455, 0.16592702], dtype=float32)

# %%
args, tree = jax.tree_util.tree_flatten(expon(1.))

# %%
jax.tree_util.tree_unflatten(tree, args)
# Out:
# expon(1.0)
